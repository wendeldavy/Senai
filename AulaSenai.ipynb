# %% [markdown]
# <a href="https://colab.research.google.com/github/wendeldavy/Senai/blob/main/AulaSenai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = 'wendel'
idade = '27'
cidade = 'camaragibe'
profissao = 'Analista de Estoque'

# %%
print ('Oi, meu nome é ' + nome + '.' + ' Tenho ' + str (idade) +  ' anos.' + ' Venho da cidade de ' + cidade + ' e sou ' + profissao + '.')
# Out:
# Oi, meu nome é wendel. Tenho 27 anos. Venho da cidade de camaragibe e sou Analista de Estoque.
